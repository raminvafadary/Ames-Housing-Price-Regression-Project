# %% [markdown]
# # Importing Libraries and Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import csv
from scipy.stats import norm, skew
from sklearn.preprocessing import PolynomialFeatures, PowerTransformer
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
import pickle

# %%
#importing data
df=pd.read_csv("../datasets/train.csv",index_col="Id")
df.head()
# Out:
#            PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# Id
# 109  533352170           60        RL           NaN     13517   Pave   NaN
# 544  531379050           60        RL          43.0     11492   Pave   NaN
# 153  535304180           20        RL          68.0      7922   Pave   NaN
# 318  916386060           60        RL          73.0      9802   Pave   NaN
# 255  906425045           50        RL          82.0     14235   Pave   NaN
#
#     Lot Shape Land Contour Utilities  ... Screen Porch Pool Area Pool QC  \
# Id                                    ...
# 109       IR1          Lvl    AllPub  ...            0         0     NaN
# 544       IR1          Lvl    AllPub  ...            0         0     NaN
# 153       Reg          Lvl    AllPub  ...            0         0     NaN
# 318       Reg          Lvl    AllPub  ...            0         0     NaN
# 255       IR1          Lvl    AllPub  ...            0         0     NaN
#
#     Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  SalePrice
# Id
# 109   NaN          NaN        0       3     2010        WD      130500
# 544   NaN          NaN        0       4     2009        WD      220000
# 153   NaN          NaN        0       1     2010        WD      109000
# 318   NaN          NaN        0       4     2010        WD      174000
# 255   NaN          NaN        0       3     2010        WD      138500
#
# [5 rows x 80 columns]

# %%
df.shape
# Out:
# (2051, 80)

# %% [markdown]
# ## Replace with numpy nan values

# %%
# replacing "nan" with np.nan
df =df.replace("nan", np.nan)

# %% [markdown]
# ## Dropping duplicate rows

# %%
df.drop_duplicates(keep="first", inplace=True)

# %%
df.shape
# Out:
# (2051, 80)

# %% [markdown]
# ## Dropping unwanted columns

# %%
df.drop(columns=["PID"],inplace=True)

# %% [markdown]
# ## Clean Corrupted columns(why the column that should be numeric is object??

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2051 entries, 109 to 10
# Data columns (total 79 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MS SubClass      2051 non-null   int64
#  1   MS Zoning        2051 non-null   object
#  2   Lot Frontage     1721 non-null   float64
#  3   Lot Area         2051 non-null   int64
#  4   Street           2051 non-null   object
#  5   Alley            140 non-null    object
#  6   Lot Shape        2051 non-null   object
#  7   Land Contour     2051 non-null   object
#  8   Utilities        2051 non-null   object
#  9   Lot Config       2051 non-null   object
#  10  Land Slope       2051 non-null   object
#  11  Neighborhood     2051 non-null   object
#  12  Condition 1      2051 non-null   object
#  13  Condition 2      2051 non-null   object
#  14  Bldg Type        2051 non-null   object
#  15  House Style      2051 non-null   object
#  16  Overall Qual     2051 non-null   int64
#  17  Overall Cond     2051 non-null   int64
#  18  Year Built       2051 non-null   int64
#  19  Year Remod/Add   2051 non-null   int64
#  20  Roof Style       2051 non-null   object
#  21  Roof Matl        2051 non-null   object
#  22  Exterior 1st     2051 non-null   object
#  23  Exterior 2nd     2051 non-null   object
#  24  Mas Vnr Type     2029 non-null   object
#  25  Mas Vnr Area     2029 non-null   float64
#  26  Exter Qual       2051 non-null   object
#  27  Exter Cond       2051 non-null   object
#  28  Foundation       2051 non-null   object
#  29  Bsmt Qual        1996 non-null   object
#  30  Bsmt Cond        1996 non-null   object
#  31  Bsmt Exposure    1993 non-null   object
#  32  BsmtFin Type 1   1996 non-null   object
#  33  BsmtFin SF 1     2050 non-null   float64
#  34  BsmtFin Type 2   1995 non-null   object
#  35  BsmtFin SF 2     2050 non-null   float64
#  36  Bsmt Unf SF      2050 non-null   float64
#  37  Total Bsmt SF    2050 non-null   float64
#  38  Heating          2051 non-null   object
#  39  Heating QC       2051 non-null   object
#  40  Central Air      2051 non-null   object
#  41  Electrical       2051 non-null   object
#  42  1st Flr SF       2051 non-null   int64
#  43  2nd Flr SF       2051 non-null   int64
#  44  Low Qual Fin SF  2051 non-null   int64
#  45  Gr Liv Area      2051 non-null   int64
#  46  Bsmt Full Bath   2049 non-null   float64
#  47  Bsmt Half Bath   2049 non-null   float64
#  48  Full Bath        2051 non-null   int64
#  49  Half Bath        2051 non-null   int64
#  50  Bedroom AbvGr    2051 non-null   int64
#  51  Kitchen AbvGr    2051 non-null   int64
#  52  Kitchen Qual     2051 non-null   object
#  53  TotRms AbvGrd    2051 non-null   int64
#  54  Functional       2051 non-null   object
#  55  Fireplaces       2051 non-null   int64
#  56  Fireplace Qu     1051 non-null   object
#  57  Garage Type      1938 non-null   object
#  58  Garage Yr Blt    1937 non-null   float64
#  59  Garage Finish    1937 non-null   object
#  60  Garage Cars      2050 non-null   float64
#  61  Garage Area      2050 non-null   float64
#  62  Garage Qual      1937 non-null   object
#  63  Garage Cond      1937 non-null   object
#  64  Paved Drive      2051 non-null   object
#  65  Wood Deck SF     2051 non-null   int64
#  66  Open Porch SF    2051 non-null   int64
#  67  Enclosed Porch   2051 non-null   int64
#  68  3Ssn Porch       2051 non-null   int64
#  69  Screen Porch     2051 non-null   int64
#  70  Pool Area        2051 non-null   int64
#  71  Pool QC          9 non-null      object
#  72  Fence            400 non-null    object
#  73  Misc Feature     65 non-null     object
#  74  Misc Val         2051 non-null   int64
#  75  Mo Sold          2051 non-null   int64
#  76  Yr Sold          2051 non-null   int64
#  77  Sale Type        2051 non-null   object
#  78  SalePrice        2051 non-null   int64
# dtypes: float64(11), int64(26), object(42)
# memory usage: 1.3+ MB

# %%
#drop unwanted columns
df.drop(columns=["Street","Alley","Fireplace Qu","Misc Feature","Fence","Pool QC","Lot Frontage"],inplace=True)

# %% [markdown]
# ## There is no corrupted column

# %% [markdown]
# ## Droping missing values in numerical data

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['Mas Vnr Type',
#  'Mas Vnr Area',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin SF 1',
#  'BsmtFin Type 2',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Garage Type',
#  'Garage Yr Blt',
#  'Garage Finish',
#  'Garage Cars',
#  'Garage Area',
#  'Garage Qual',
#  'Garage Cond']

# %% [markdown]
# ## Filling missing values for columns with large number of missing values for numerical data

# %%
#imputing with mean
df = df.fillna(df.median().iloc[0])

# %% [markdown]
# ## Filling missing values for columns with large number of missing values for categorical data

# %%
df = df.fillna(df.mode().iloc[0])

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                   count           mean           std      min       25%  \
# MS SubClass      2051.0      57.008776     42.824223     20.0      20.0
# Lot Area         2051.0   10065.208191   6742.488909   1300.0    7500.0
# Overall Qual     2051.0       6.112140      1.426271      1.0       5.0
# Overall Cond     2051.0       5.562165      1.104497      1.0       5.0
# Year Built       2051.0    1971.708922     30.177889   1872.0    1953.5
# Year Remod/Add   2051.0    1984.190151     21.036250   1950.0    1964.5
# Mas Vnr Area     2051.0      99.162847    174.097088      0.0       0.0
# BsmtFin SF 1     2051.0     442.109215    461.172982      0.0       0.0
# BsmtFin SF 2     2051.0      47.960020    164.960659      0.0       0.0
# Bsmt Unf SF      2051.0     567.475865    444.993115      0.0     220.0
# Total Bsmt SF    2051.0    1057.496343    449.852027      0.0     793.0
# 1st Flr SF       2051.0    1164.488055    396.446923    334.0     879.5
# 2nd Flr SF       2051.0     329.329108    425.671046      0.0       0.0
# Low Qual Fin SF  2051.0       5.512921     51.068870      0.0       0.0
# Gr Liv Area      2051.0    1499.330083    500.447829    334.0    1129.0
# Bsmt Full Bath   2051.0       0.475865      1.633425      0.0       0.0
# Bsmt Half Bath   2051.0       0.112140      1.579164      0.0       0.0
# Full Bath        2051.0       1.577279      0.549279      0.0       1.0
# Half Bath        2051.0       0.371039      0.501043      0.0       0.0
# Bedroom AbvGr    2051.0       2.843491      0.826618      0.0       2.0
# Kitchen AbvGr    2051.0       1.042906      0.209790      0.0       1.0
# TotRms AbvGrd    2051.0       6.435885      1.560225      2.0       5.0
# Fireplaces       2051.0       0.590931      0.638516      0.0       0.0
# Garage Yr Blt    2051.0    1871.505119    442.692594     50.0    1957.0
# Garage Cars      2051.0       1.800098      1.310751      0.0       1.0
# Garage Area      2051.0     473.465139    216.084489      0.0     319.0
# Wood Deck SF     2051.0      93.833740    128.549416      0.0       0.0
# Open Porch SF    2051.0      47.556802     66.747241      0.0       0.0
# Enclosed Porch   2051.0      22.571916     59.845110      0.0       0.0
# 3Ssn Porch       2051.0       2.591419     25.229615      0.0       0.0
# Screen Porch     2051.0      16.511458     57.374204      0.0       0.0
# Pool Area        2051.0       2.397855     37.782570      0.0       0.0
# Misc Val         2051.0      51.574354    573.393985      0.0       0.0
# Mo Sold          2051.0       6.219893      2.744736      1.0       4.0
# Yr Sold          2051.0    2007.775719      1.312014   2006.0    2007.0
# SalePrice        2051.0  181469.701609  79258.659352  12789.0  129825.0
#
#                       50%       75%       max
# MS SubClass          50.0      70.0     190.0
# Lot Area           9430.0   11513.5  159000.0
# Overall Qual          6.0       7.0      10.0
# Overall Cond          5.0       6.0       9.0
# Year Built         1974.0    2001.0    2010.0
# Year Remod/Add     1993.0    2004.0    2010.0
# Mas Vnr Area          0.0     159.0    1600.0
# BsmtFin SF 1        368.0     733.5    5644.0
# BsmtFin SF 2          0.0       0.0    1474.0
# Bsmt Unf SF         474.0     811.0    2336.0
# Total Bsmt SF       994.0    1318.5    6110.0
# 1st Flr SF         1093.0    1405.0    5095.0
# 2nd Flr SF            0.0     692.5    1862.0
# Low Qual Fin SF       0.0       0.0    1064.0
# Gr Liv Area        1444.0    1728.5    5642.0
# Bsmt Full Bath        0.0       1.0      50.0
# Bsmt Half Bath        0.0       0.0      50.0
# Full Bath             2.0       2.0       4.0
# Half Bath             0.0       1.0       2.0
# Bedroom AbvGr         3.0       3.0       8.0
# Kitchen AbvGr         1.0       1.0       3.0
# TotRms AbvGrd         6.0       7.0      15.0
# Fireplaces            1.0       1.0       4.0
# Garage Yr Blt      1978.0    2001.0    2207.0
# Garage Cars           2.0       2.0      50.0
# Garage Area         480.0     576.0    1418.0
# Wood Deck SF          0.0     168.0    1424.0
# Open Porch SF        27.0      70.0     547.0
# Enclosed Porch        0.0       0.0     432.0
# 3Ssn Porch            0.0       0.0     508.0
# Screen Porch          0.0       0.0     490.0
# Pool Area             0.0       0.0     800.0
# Misc Val              0.0       0.0   17000.0
# Mo Sold               6.0       8.0      12.0
# Yr Sold            2008.0    2009.0    2010.0
# SalePrice        162500.0  214000.0  611657.0

# %%
df.shape
# Out:
# (2051, 72)

# %% [markdown]
# # Visaullization

# %% [markdown]
# ## Finding outliers

# %%
#function to plot in subplots and one figure of box plots
def subplot_boxplot(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/3)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=3,figsize=(20, 40)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].boxplot(dataframe[column],'red')
        ax[i].set_title(str(list_of_titles[i]))# feel free to add more settings
        # Set titles, labels, etc here for each subplot

# %%
list_of_titles_boxplots=[]
for items in list(df.select_dtypes(exclude=['object']).columns):
    list_of_titles_boxplots.append("Box Plot of"+" "+items)

# %%
subplot_boxplot(df,list(df.select_dtypes(exclude=['object']).columns),list_of_titles_boxplots, None)
plt.savefig('../plots/boxplots1.png', dpi=235)

# %% [markdown]
# ## Handling outliers

# %%
df.head()
# Out:
#      MS SubClass MS Zoning  Lot Area Lot Shape Land Contour Utilities  \
# Id
# 109           60        RL     13517       IR1          Lvl    AllPub
# 544           60        RL     11492       IR1          Lvl    AllPub
# 153           20        RL      7922       Reg          Lvl    AllPub
# 318           60        RL      9802       Reg          Lvl    AllPub
# 255           50        RL     14235       IR1          Lvl    AllPub
#
#     Lot Config Land Slope Neighborhood Condition 1  ... Open Porch SF  \
# Id                                                  ...
# 109    CulDSac        Gtl       Sawyer        RRAe  ...            44
# 544    CulDSac        Gtl      SawyerW        Norm  ...            74
# 153     Inside        Gtl        NAmes        Norm  ...            52
# 318     Inside        Gtl       Timber        Norm  ...             0
# 255     Inside        Gtl      SawyerW        Norm  ...            59
#
#     Enclosed Porch 3Ssn Porch  Screen Porch  Pool Area  Misc Val  Mo Sold  \
# Id
# 109              0          0             0          0         0        3
# 544              0          0             0          0         0        4
# 153              0          0             0          0         0        1
# 318              0          0             0          0         0        4
# 255              0          0             0          0         0        3
#
#     Yr Sold Sale Type SalePrice
# Id
# 109    2010       WD     130500
# 544    2009       WD     220000
# 153    2010       WD     109000
# 318    2010       WD     174000
# 255    2010       WD     138500
#
# [5 rows x 72 columns]

# %%
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
df=remove_outlier(df,"SalePrice")

# %% [markdown]
# ### Note that there are 2 extremely low price outliers

# %%
df[df.SalePrice < 20000]
# Out:
#       MS SubClass MS Zoning  Lot Area Lot Shape Land Contour Utilities  \
# Id
# 1554           20   A (agr)     14584       Reg          Low    AllPub
# 182            30        RM      9656       Reg          Lvl    AllPub
#
#      Lot Config Land Slope Neighborhood Condition 1  ... Open Porch SF  \
# Id                                                   ...
# 1554     Inside        Mod       IDOTRR        Norm  ...             0
# 182      Inside        Gtl      OldTown        Norm  ...             0
#
#      Enclosed Porch 3Ssn Porch  Screen Porch  Pool Area  Misc Val  Mo Sold  \
# Id
# 1554              0          0             0          0         0        2
# 182               0          0             0          0         0        6
#
#      Yr Sold Sale Type SalePrice
# Id
# 1554    2008       WD      13100
# 182     2010       WD      12789
#
# [2 rows x 72 columns]

# %%
df.drop(index=[182, 1554], inplace=True)

# %% [markdown]
# ## Heat map

# %%
plt.figure(figsize=(8, 20))
sns.heatmap(df.corr()[["SalePrice"]].sort_values("SalePrice"),
            annot=True, 
            cmap="coolwarm",
           vmin=-1,
           vmax=1)
plt.savefig('../plots/heatmap1.png', dpi=235)

# %%
# Out:
#              level_0         level_1         0
# 0        MS SubClass     MS SubClass  1.000000
# 2        MS SubClass      Year Built  0.055365
# 3        MS SubClass  Year Remod/Add  0.061525
# 4        MS SubClass    Mas Vnr Area  0.033138
# 10       MS SubClass      2nd Flr SF  0.306932
# ...              ...             ...       ...
# 65521  Sale Type_WD   Garage Cond_Ex  0.011627
# 65523  Sale Type_WD   Garage Cond_Gd  0.028555
# 65524  Sale Type_WD   Garage Cond_Po  0.021781
# 65526  Sale Type_WD    Paved Drive_P  0.029044
# 65535  Sale Type_WD    Sale Type_WD   1.000000
#
# [19374 rows x 3 columns]

# %% [markdown]
# ## Use sklearn feature polynomial

# %%
features=X.columns.tolist()

# %%
poly = PolynomialFeatures(include_bias=False)

# %%
X_poly = poly.fit_transform(X)

# %%
#X=pd.DataFrame(X_poly, columns=poly.get_feature_names(features))

# %% [markdown]
# ## Encode a couple of discrete numeric columns as object before dummying

# %%
df[['Overall Cond', 'Overall Qual']] = df[['Overall Cond', 'Overall Qual']].astype('object')

# %% [markdown]
# ## Changing the categorical data to dummies

# %%
df.select_dtypes(include=["object"])
# Out:
#      MS Zoning Lot Shape Land Contour Utilities Lot Config Land Slope  \
# Id
# 109         RL       IR1          Lvl    AllPub    CulDSac        Gtl
# 544         RL       IR1          Lvl    AllPub    CulDSac        Gtl
# 153         RL       Reg          Lvl    AllPub     Inside        Gtl
# 318         RL       Reg          Lvl    AllPub     Inside        Gtl
# 255         RL       IR1          Lvl    AllPub     Inside        Gtl
# ...        ...       ...          ...       ...        ...        ...
# 1587        RL       IR1          HLS    AllPub     Inside        Gtl
# 785         RL       IR1          Lvl    AllPub     Inside        Gtl
# 916         RL       Reg          Bnk    AllPub     Inside        Gtl
# 639         RL       Reg          Lvl    AllPub     Corner        Gtl
# 10          RL       Reg          Lvl    AllPub     Inside        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type  ... Central Air  \
# Id                                                   ...
# 109        Sawyer        RRAe        Norm      1Fam  ...           Y
# 544       SawyerW        Norm        Norm      1Fam  ...           Y
# 153         NAmes        Norm        Norm      1Fam  ...           Y
# 318        Timber        Norm        Norm      1Fam  ...           Y
# 255       SawyerW        Norm        Norm      1Fam  ...           Y
# ...           ...         ...         ...       ...  ...         ...
# 1587       Timber        Norm        Norm      1Fam  ...           Y
# 785       Edwards        Norm        Norm      1Fam  ...           Y
# 916       Crawfor        Norm        Norm      1Fam  ...           Y
# 639         NAmes        Norm        Norm      1Fam  ...           Y
# 10        Gilbert        Norm        Norm      1Fam  ...           Y
#
#      Electrical Kitchen Qual Functional Garage Type Garage Finish Garage Qual  \
# Id
# 109       SBrkr           Gd        Typ      Attchd           RFn          TA
# 544       SBrkr           Gd        Typ      Attchd           RFn          TA
# 153       SBrkr           Gd        Typ      Detchd           Unf          TA
# 318       SBrkr           TA        Typ     BuiltIn           Fin          TA
# 255       SBrkr           TA        Typ      Detchd           Unf          TA
# ...         ...          ...        ...         ...           ...         ...
# 1587      SBrkr           Gd        Typ      Attchd           Fin          TA
# 785       SBrkr           TA        Typ      Detchd           Unf          TA
# 916       SBrkr           TA        Typ      Detchd           Unf          Fa
# 639       SBrkr           TA        Typ      Attchd           Unf          TA
# 10        SBrkr           Gd        Typ      Attchd           Fin          TA
#
#      Garage Cond Paved Drive Sale Type
# Id
# 109           TA           Y       WD
# 544           TA           Y       WD
# 153           TA           Y       WD
# 318           TA           Y       WD
# 255           TA           N       WD
# ...          ...         ...       ...
# 1587          TA           Y       WD
# 785           TA           Y       WD
# 916           Fa           Y       WD
# 639           TA           Y       WD
# 10            TA           Y       WD
#
# [1955 rows x 38 columns]

# %%
df = pd.get_dummies(df, drop_first = True)

# %%
df.head()
# Out:
#      MS SubClass  Lot Area  Year Built  Year Remod/Add  Mas Vnr Area  \
# Id
# 109           60     13517        1976            2005         289.0
# 544           60     11492        1996            1997         132.0
# 153           20      7922        1953            2007           0.0
# 318           60      9802        2006            2007           0.0
# 255           50     14235        1900            1993           0.0
#
#      BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  1st Flr SF  ...  \
# Id                                                                       ...
# 109         533.0           0.0        192.0          725.0         725  ...
# 544         637.0           0.0        276.0          913.0         913  ...
# 153         731.0           0.0        326.0         1057.0        1057  ...
# 318           0.0           0.0        384.0          384.0         744  ...
# 255           0.0           0.0        676.0          676.0         831  ...
#
#      Paved Drive_P  Paved Drive_Y  Sale Type_CWD  Sale Type_Con  \
# Id
# 109              0              1              0              0
# 544              0              1              0              0
# 153              0              1              0              0
# 318              0              1              0              0
# 255              0              0              0              0
#
#      Sale Type_ConLD  Sale Type_ConLI  Sale Type_ConLw  Sale Type_New  \
# Id
# 109                0                0                0              0
# 544                0                0                0              0
# 153                0                0                0              0
# 318                0                0                0              0
# 255                0                0                0              0
#
#      Sale Type_Oth  Sale Type_WD
# Id
# 109              0              1
# 544              0              1
# 153              0              1
# 318              0              1
# 255              0              1
#
# [5 rows x 256 columns]

# %% [markdown]
# ### Heat map

# %%
plt.figure(figsize=(8, 50))
sns.heatmap(df.corr()[["SalePrice"]].sort_values("SalePrice"),
            annot=True, 
            cmap="coolwarm",
           vmin=-1,
           vmax=1)
plt.savefig('../plots/heatmap2.png', dpi=235)

# %% [markdown]
# # Skewness of the output

# %% [markdown]
# ## histogram plot

# %%
sns.distplot(df['SalePrice'] , fit=norm);

# %%
#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(df['SalePrice'], plot=plt)
plt.show()

# %%
df["price_log"]=df["SalePrice"].map(np.log)

# %%
#Check the new distribution 
sns.distplot(df['price_log'] , fit=norm);

# %%
#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(df['price_log'], plot=plt)
plt.show()

# %% [markdown]
# ## it shows we need to transform the output

# %%
df.drop(columns=["price_log"],inplace=True)

# %%
pt_y = PowerTransformer()

# %%
pt_y.fit(df.SalePrice.to_frame())
# Out:
# PowerTransformer(copy=True, method='yeo-johnson', standardize=True)

# %%
df["SalePrice_pt"] = pt_y.transform(df.SalePrice.to_frame())

# %%
#Check the new distribution 
sns.distplot(df['SalePrice_pt'] , fit=norm);

# %%
#Get also the QQ-plot
fig = plt.figure()
res = stats.probplot(df['SalePrice_pt'], plot=plt)
plt.show()

# %%
df.drop(columns=["SalePrice_pt"],inplace=True)

# %% [markdown]
# ## Model Prep: Create our features matrix (`X`) and target vector (`y`)

# %%
X = df.drop('SalePrice', axis = 1)
y = df['SalePrice']

# %%
# the number of features
len(X.columns)
# Out:
# 255

# %%
## Create column list for future alignment

# %%
columns = X.columns

# %%
with open('../assets/columns.pkl', 'wb+') as f:
    pickle.dump(list(X.columns), f)

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Combining Features

# %% [markdown]
# # Interaction terms

# %% [markdown]
# ## Manually drop the collinear features

# %%
# from statsmodels.stats.outliers_influence import variance_inflation_factor    

# def calculate_vif_(X, thresh=100):
#     cols = X.columns
#     variables = np.arange(X.shape[1])
#     dropped=True
#     while dropped:
#         dropped=False
#         c = X[cols[variables]].values
#         vif = [variance_inflation_factor(c, ix) for ix in np.arange(c.shape[1])]

#         maxloc = vif.index(max(vif))
#         if max(vif) > thresh:
#             print('dropping \'' + X[cols[variables]].columns[maxloc] + '\' at index: ' + str(maxloc))
#             variables = np.delete(variables, maxloc)
#             dropped=True

#     print('Remaining variables:')
#     print(X.columns[variables])
#     return X[cols[variables]]

# %%
# calculate_vif_(df.drop("SalePrice"), thresh=100)

# %% [markdown]
# ## Apply Variance Threshold to remove low variance features

# %%
#threshold = VarianceThreshold(10000000)

# %%
#X_t= threshold.fit_transform(X)

# %%
#columns = X.columns[threshold.get_support()]

# %%
#X=pd.DataFrame(X_t, columns=columns)

# %% [markdown]
# ## Neighbors

# %%
# train_df = pd.get_dummies(train_df)
# train_df.head()
# neighborhoods_vars = list(train_df.filter(regex = 'Neighborhood').columns)
# features = features + neighborhoods_vars
# features

# %% [markdown]
# # Pre-Processing

# %% [markdown]
# ## One-hot encode categorical variables

# %% [markdown]
# ## Using automated feature selection

# %% [markdown]
# ## Model Prep: Train/test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state = 42 )

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## export the final data

# %%
X_train.to_csv('../datasets/X_train.csv')

# %%
X_test.to_csv('../datasets/X_test.csv')

# %%
y_train.to_pickle('../datasets/y_train.csv')

# %%
y_test.to_pickle('../datasets/y_test.csv')

# %%
#save the trained dataframe
df.to_csv('../datasets/train_df.csv')
